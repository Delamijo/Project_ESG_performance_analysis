# %% [markdown]
# # Data export

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine, text
from pathlib import Path

# %% [markdown]
# ## Data

# %%
base_ordner = Path().resolve().parent
proc_data_ordner = base_ordner / "data" / "processed"

df_l        = pd.read_csv(proc_data_ordner / "lauschke_kpis.csv")
df_comp     = pd.read_csv(proc_data_ordner / "lauschke_benchmark.csv")
df_bench    = pd.read_csv(proc_data_ordner / "benchmark.csv")
df_yearly   = pd.read_csv(proc_data_ordner / "bench_yearly.csv")
df_forecast = pd.read_csv(proc_data_ordner / "forecast_2030.csv")
df_corr     = pd.read_csv(proc_data_ordner / "corr_per_company.csv")

print("Alle Datensätze geladen")
# Out:
# Alle Datensätze geladen
